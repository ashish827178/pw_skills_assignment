# %% [raw]
# Q1: Explain the following with an example:
# 1) Artificial Intelligence
# 2) Machine Learning,
# 3) Deep Learning
#
# Artificial Intelligence (AI):
#
# Definition: Artificial Intelligence refers to the development of computer systems that can perform tasks that typically require human intelligence. It involves creating algorithms and systems that can think, learn, and problem-solve like humans.
#
# Example: A common example is virtual personal assistants like Siri, Google Assistant, or Alexa. These AI-driven systems can understand and respond to voice commands, answer questions, and perform tasks like setting reminders or sending messages.
#
# Machine Learning (ML):
#
# Definition: Machine Learning is a subset of AI that focuses on developing algorithms and models that allow computers to learn from and make predictions or decisions based on data. It involves training a model on data to improve its performance on a specific task.
#
# Example: Email spam filters are a classic example of machine learning. These filters analyze your email content and learn to distinguish between spam and non-spam emails based on patterns in the data. Over time, they become better at identifying spam.
#
# Deep Learning:
#
# Definition: Deep Learning is a subfield of machine learning that uses artificial neural networks to model and solve complex problems. It's called "deep" because it involves neural networks with many layers (deep neural networks).
#
# Example: Image recognition is a common application of deep learning. For instance, in autonomous vehicles, deep learning models can analyze real-time camera images to identify objects like pedestrians, traffic signs, and other vehicles.

# %% [raw]
# Q2- What is supervised learning? List some examples of supervised learning.
#
# Supervised learning is a type of machine learning where an algorithm learns from labeled training data to make predictions or decisions without being explicitly programmed. In supervised learning, the algorithm learns the relationship between input data (features) and corresponding target labels, aiming to map new, unseen data to the correct labels. It's called "supervised" because the algorithm is guided by the labeled data during training.
#
# Examples of supervised learning include:
#
# Email spam detection
# House price prediction
# Handwritten recognition

# %% [raw]
# Q2- What is unsupervised learning? List some examples of unsupervised learning.
#
# Unsupervised learning is a type of machine learning where the algorithm learns from unlabeled data, aiming to discover patterns, structures, or relationships within the data without explicit guidance. In unsupervised learning, the algorithm doesn't have access to target labels or outcomes; instead, it explores the inherent structure or distribution within the data.
#
# Examples of unsupervised learning include:
#
# Clustering: Clustering algorithms group data points into clusters or categories based on their similarities. Common clustering techniques include:
#
# K-Means Clustering: Dividing data into K clusters where each data point belongs to the cluster with the nearest mean.
# Hierarchical Clustering: Creating a tree-like hierarchy of clusters, allowing for various levels of granularity.
#
# Dimensionality Reduction: These algorithms aim to reduce the number of features or dimensions in a dataset while preserving important information. Examples include:
#
# Principal Component Analysis (PCA): Reducing dimensionality by transforming data into a new coordinate system.

# %% [raw]
# Q4- What is the difference between AI, ML, DL, and DS?
#
# Artificial Intelligence (AI):
#
# Definition: AI is a broad field of computer science focused on creating systems or machines that can perform tasks that typically require human intelligence. It aims to simulate human-like cognitive functions such as reasoning, problem-solving, learning, perception, and natural language understanding.
#
# Machine Learning (ML):
#
# Definition: ML is a subset of AI that focuses on developing algorithms and models that enable computers to learn from and make predictions or decisions based on data. ML algorithms improve their performance on a specific task through exposure to data.
#
# Deep Learning (DL):
#
# Definition: DL is a subfield of ML that uses artificial neural networks to model and solve complex problems. Deep neural networks consist of multiple layers (deep networks) and are particularly effective at tasks involving large amounts of data, such as image and speech recognition.
#
# Data Science (DS):
#
# Definition: DS is an interdisciplinary field that combines domain expertise, programming skills, and statistical knowledge to extract insights and knowledge from data. Data scientists collect, clean, analyze, and interpret data to inform decision-making.

# %% [raw]
# Q5- What are the main differences between supervised, unsupervised, and semi-supervised learning
#
# Supervised Learning:
#
# Data: we have data with labels (e.g., pictures of cats and dogs labeled as "cat" or "dog").
# Goal: The computer learns to make predictions or decisions based on this labeled data.
# Examples: Teaching a computer to recognize cats and dogs in pictures.
#
# Unsupervised Learning:
#
# Data: we have data without labels (just a bunch of pictures, no "cat" or "dog" labels).
# Goal: The computer tries to find patterns or groups in this data on its own.
# Examples: Grouping similar pictures together without knowing what's in them.
#
# Semi-Supervised Learning:
#
# Data: we have a mix of labeled data (some pictures with labels) and unlabeled data (more pictures without labels).
# Goal: we use the labeled data to help the computer make better sense of the unlabeled data.
# Examples: If we have some labeled cat pictures, we use them to help the computer recognize more cats in the unlabeled pictures.

# %% [raw]
# Q6- What is train, test and validation split? Explain the importance of each term.
#
# Training Set:
#
# The training set is the largest portion of the data used for training a machine learning model.
# The training set is crucial because it's where the model learns from the data.
#
# Validation Set:
#
# The validation set is a separate portion of the data that the model does not see during training. It's used to fine-tune model hyperparameters and assess its performance during development.
# The validation set helps in preventing overfitting, which occurs when a model learns to fit the training data too closely but doesn't generalize well to new, unseen data.
#
# Test Set:
#
# Purpose: The test set is a completely independent portion of the data that the model has never seen before. It's used to evaluate the final performance and generalization of the trained model.
# Importance: The test set provides an unbiased assessment of how well the model will perform on new, unseen data.
#
# Importance of Each Set:
#
# Training Set: This is where the model learns and forms its understanding of the data. Without a proper training set, the model won't be able to make accurate predictions.
#
# Validation Set: This set helps in selecting the best model hyperparameters and detecting any issues with overfitting. It acts as a guide to improve the model's performance.
#
# Test Set: The test set provides an objective measure of how well the model will perform in the real world. It's essential for assessing the model's readiness for deployment.

# %% [raw]
# Q7- How can unsupervised learning be used in anomaly detection?
#
#
# Unsupervised learning is a powerful approach for anomaly detection because it can automatically identify patterns and anomalies in data without the need for labeled examples of anomalies.
#
# Grouping Similar Data: Unsupervised learning can group similar data points together automatically. It's like sorting items that look alike into piles.
#
# Identifying Odd Ones Out: Any data point that doesn't fit well into any group or pile is considered an anomaly. It's like finding the odd item that doesn't belong with the others.
#
# Examples: Think of finding unusual patterns in credit card transactions to detect fraud, spotting unusual behavior in computer networks to identify security breaches, or discovering unusual medical test results that indicate health problems.

# %% [raw]
# Q8- List down some commonly used supervised learning algorithms and unsupervised learning algorithms.
#
# Supervised Learning Algorithms:
#
# Linear Regression: Predicts a continuous target variable based on input features. Used for tasks like predicting prices.
#
# Logistic Regression: Used for binary classification tasks like spam vs. non-spam email classification.
#
# Decision Trees: Tree-based models that can handle both classification and regression tasks.
#
# Random Forest: An ensemble method using multiple decision trees. Great for various tasks, including classification and regression.
#
# Support Vector Machines (SVM): Effective for classification tasks by finding a hyperplane that best separates data into classes.
#
# Naive Bayes: Especially useful for text classification and spam detection.
#
# K-Nearest Neighbors (K-NN): Classifies data points based on the majority class among their k-nearest neighbors.
#
# Neural Networks: Deep learning models used for various tasks, including image and speech recognition.
#
# Unsupervised Learning Algorithms:
#
# K-Means Clustering: Groups data into clusters based on similarity. Useful for customer segmentation and image compression.
#
# Hierarchical Clustering: Builds a hierarchy of clusters, often represented as a dendrogram.
#
# DBSCAN (Density-Based Spatial Clustering of Applications with Noise): Great for identifying clusters with varying shapes and sizes.
#
# PCA (Principal Component Analysis): Reduces data dimensionality while preserving as much information as possible.
#
# Autoencoders: Used for dimensionality reduction, feature learning, and anomaly detection.
#
# Isolation Forest: An efficient method for anomaly detection by isolating unusual data points.
#
# Gaussian Mixture Models (GMM): Models data as a mixture of multiple Gaussian distributions.
#
# Self-Organizing Maps (SOM): Useful for visualizing high-dimensional data in lower dimensions.
#
# t-SNE (t-Distributed Stochastic Neighbor Embedding): Effective for visualizing and exploring high-dimensional data.
